# %% [markdown]
# # COVID-19

# %%
# Importing required libraries
import json
import requests
import pprint
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
# Getting and formatting data
data = json.loads(requests.get("https://pomber.github.io/covid19/timeseries.json").text)
country_names = list(data.keys())
column_names = []
column_names.append('country')
json_keys = list(data['Afghanistan'][0].keys())
column_names.extend(json_keys)
data_pd = pd.DataFrame(columns = column_names)
date_list = []
confirmed_list = []
deaths_list = []
recovered_list = []
country_list = []
for country in country_names:
  for item in list(data[country]):
    country_list.append(country)
    date_list.append(item['date'])
    confirmed_list.append(item['confirmed'])
    deaths_list.append(item['deaths'])
    recovered_list.append(item['recovered'])
data_pd['country'] = country_list
data_pd['date'] = date_list
data_pd['confirmed'] = confirmed_list
data_pd['deaths'] = deaths_list
data_pd['recovered'] = recovered_list
data_pd.tail()
# Out:
#        country       date  confirmed  deaths  recovered
# 25375  Lesotho  2020-5-31          2       0          1
# 25376  Lesotho   2020-6-1          2       0          1
# 25377  Lesotho   2020-6-2          2       0          1
# 25378  Lesotho   2020-6-3          4       0          2
# 25379  Lesotho   2020-6-4          4       0          2

# %%
data_pd.columns
# Out:
# Index(['country', 'date', 'confirmed', 'deaths', 'recovered'], dtype='object')

# %%
c = list(data_pd['confirmed'])
c_new = [c[0]]
d = list(data_pd['deaths'])
d_new = [d[0]]
r = list(data_pd['recovered'])
r_new = [r[0]]

for a,b in zip(c,c[1:]):
    c_new.append(b-a)
for a,b in zip(d,d[1:]):
    d_new.append(b-a)
for a,b in zip(r,r[1:]):
    r_new.append(b-a)

data_pd['daily_confirmed'] = c_new
data_pd['daily_deaths'] = d_new
data_pd['daily_recoveries'] = r_new

data_pd.iloc[80:,:]
# Out:
#            country       date  confirmed  deaths  recovered  daily_confirmed  \
# 80     Afghanistan  2020-4-11        555      18         32               34
# 81     Afghanistan  2020-4-12        607      18         32               52
# 82     Afghanistan  2020-4-13        665      21         32               58
# 83     Afghanistan  2020-4-14        714      23         40               49
# 84     Afghanistan  2020-4-15        784      25         43               70
# ...            ...        ...        ...     ...        ...              ...
# 25375      Lesotho  2020-5-31          2       0          1                0
# 25376      Lesotho   2020-6-1          2       0          1                0
# 25377      Lesotho   2020-6-2          2       0          1                0
# 25378      Lesotho   2020-6-3          4       0          2                2
# 25379      Lesotho   2020-6-4          4       0          2                0
#
#        daily_deaths  daily_recoveries
# 80                3                 0
# 81                0                 0
# 82                3                 0
# 83                2                 8
# 84                2                 3
# ...             ...               ...
# 25375             0                 0
# 25376             0                 0
# 25377             0                 0
# 25378             0                 1
# 25379             0                 0
#
# [25300 rows x 8 columns]

# %%
print(data_pd.shape)
# Out:
# (25380, 5)

# %%
print(data_pd.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25380 entries, 0 to 25379
# Data columns (total 5 columns):
# country      25380 non-null object
# date         25380 non-null object
# confirmed    25380 non-null int64
# deaths       25380 non-null int64
# recovered    25380 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 991.5+ KB
# None

# %%
data_pd.describe()
# Out:
#           confirmed         deaths      recovered
# count  2.538000e+04   25380.000000   25380.000000
# mean   9.622638e+03     624.002876    3338.023601
# std    6.781375e+04    4541.347149   18877.756173
# min    0.000000e+00       0.000000       0.000000
# 25%    0.000000e+00       0.000000       0.000000
# 50%    2.900000e+01       0.000000       3.000000
# 75%    9.770000e+02      20.000000     209.000000
# max    1.872660e+06  108211.000000  485002.000000

# %%
# Kenyan data
df_kenya = data_pd[data_pd['country'] == 'Kenya']
df_kenya['date'] = pd.to_datetime(df_kenya['date'])
df_kenya.info()
# Out:
# C:\Users\Cheye\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135 entries, 11070 to 11204
# Data columns (total 5 columns):
# country      135 non-null object
# date         135 non-null datetime64[ns]
# confirmed    135 non-null int64
# deaths       135 non-null int64
# recovered    135 non-null int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 6.3+ KB

# %%
features = ['confirmed','deaths','recovered']
df_kenya[features].hist(figsize=(18,6),layout=(1, 3));

# %%
df_kenya[features].plot(kind='density', subplots=True, layout=(1, 3), 
                  sharex=False, figsize=(18, 6));

# %%
plt.figure(figsize=(15, 7))
trend_df = df_kenya.set_index('date')
plt.plot(trend_df.confirmed)
plt.show()

# %%
c = list(trend_df['confirmed'])
c_new = [c[0]]
d = list(trend_df['deaths'])
d_new = [d[0]]
r = list(trend_df['recovered'])
r_new = [r[0]]

for a,b in zip(c,c[1:]):
    c_new.append(b-a)
for a,b in zip(d,d[1:]):
    d_new.append(b-a)
for a,b in zip(r,r[1:]):
    r_new.append(b-a)

trend_df['daily_confirmed'] = c_new
trend_df['daily_deaths'] = d_new
trend_df['daily_recoveries'] = r_new

trend_df.iloc[80:,:]
# Out:
#            country  confirmed  deaths  recovered  confirmed_d  deaths_d  \
# date
# 2020-04-11   Kenya        191       7         24          191         7
# 2020-04-12   Kenya        197       8         25          197         8
# 2020-04-13   Kenya        208       9         40          208         9
# 2020-04-14   Kenya        216       9         41          216         9
# 2020-04-15   Kenya        225      10         53          225        10
# 2020-04-16   Kenya        234      11         53          234        11
# 2020-04-17   Kenya        246      11         53          246        11
# 2020-04-18   Kenya        262      12         60          262        12
# 2020-04-19   Kenya        270      14         67          270        14
# 2020-04-20   Kenya        281      14         69          281        14
# 2020-04-21   Kenya        296      14         74          296        14
# 2020-04-22   Kenya        303      14         74          303        14
# 2020-04-23   Kenya        320      14         89          320        14
# 2020-04-24   Kenya        336      14         94          336        14
# 2020-04-25   Kenya        343      14         98          343        14
# 2020-04-26   Kenya        355      14        106          355        14
# 2020-04-27   Kenya        363      14        114          363        14
# 2020-04-28   Kenya        374      14        124          374        14
# 2020-04-29   Kenya        384      15        129          384        15
# 2020-04-30   Kenya        396      17        144          396        17
# 2020-05-01   Kenya        411      21        150          411        21
# 2020-05-02   Kenya        435      22        152          435        22
# 2020-05-03   Kenya        465      24        167          465        24
# 2020-05-04   Kenya        490      24        173          490        24
# 2020-05-05   Kenya        535      24        182          535        24
# 2020-05-06   Kenya        582      26        190          582        26
# 2020-05-07   Kenya        607      29        197          607        29
# 2020-05-08   Kenya        621      29        202          621        29
# 2020-05-09   Kenya        649      30        207          649        30
# 2020-05-10   Kenya        672      32        239          672        32
# 2020-05-11   Kenya        700      33        251          700        33
# 2020-05-12   Kenya        715      36        259          715        36
# 2020-05-13   Kenya        737      40        281          737        40
# 2020-05-14   Kenya        758      42        284          758        42
# 2020-05-15   Kenya        781      45        284          781        45
# 2020-05-16   Kenya        830      50        301          830        50
