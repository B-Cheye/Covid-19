# %% [markdown]
# # COVID-19

# %%
# Importing required libraries
import json
import requests
import pprint
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
# Getting and formatting data
data = json.loads(requests.get("https://pomber.github.io/covid19/timeseries.json").text)
country_names = list(data.keys())
column_names = []
column_names.append('country')
json_keys = list(data['Afghanistan'][0].keys())
column_names.extend(json_keys)
data_pd = pd.DataFrame(columns = column_names)
date_list = []
confirmed_list = []
deaths_list = []
recovered_list = []
country_list = []
for country in country_names:
  for item in list(data[country]):
    country_list.append(country)
    date_list.append(item['date'])
    confirmed_list.append(item['confirmed'])
    deaths_list.append(item['deaths'])
    recovered_list.append(item['recovered'])
data_pd['country'] = country_list
data_pd['date'] = date_list
data_pd['confirmed'] = confirmed_list
data_pd['deaths'] = deaths_list
data_pd['recovered'] = recovered_list
data_pd.tail()
# Out:
#        country       date  confirmed  deaths  recovered
# 29323  Lesotho  2020-6-21          4       0          2
# 29324  Lesotho  2020-6-22         12       0          2
# 29325  Lesotho  2020-6-23         17       0          2
# 29326  Lesotho  2020-6-24         17       0          2
# 29327  Lesotho  2020-6-25         17       0          2

# %%
data_pd.columns
# Out:
# Index(['country', 'date', 'confirmed', 'deaths', 'recovered'], dtype='object')

# %%
print(data_pd.shape)
# Out:
# (29328, 5)

# %%
print(data_pd.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29328 entries, 0 to 29327
# Data columns (total 5 columns):
# country      29328 non-null object
# date         29328 non-null object
# confirmed    29328 non-null int64
# deaths       29328 non-null int64
# recovered    29328 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB
# None

# %%
data_pd.describe()
# Out:
#           confirmed         deaths      recovered
# count  2.932800e+04   29328.000000   29328.000000
# mean   1.414192e+04     855.847620    5682.078526
# std    9.216176e+04    5719.724361   30891.313299
# min    0.000000e+00       0.000000       0.000000
# 25%    0.000000e+00       0.000000       0.000000
# 50%    8.400000e+01       1.000000      12.000000
# 75%    1.739000e+03      38.000000     555.000000
# max    2.422299e+06  124410.000000  679524.000000

# %%
# Kenyan data
df_kenya = data_pd[data_pd['country'] == 'Kenya']
df_kenya.head(20)
# Out:
#       country       date  confirmed  deaths  recovered
# 12792   Kenya  2020-1-22          0       0          0
# 12793   Kenya  2020-1-23          0       0          0
# 12794   Kenya  2020-1-24          0       0          0
# 12795   Kenya  2020-1-25          0       0          0
# 12796   Kenya  2020-1-26          0       0          0
# 12797   Kenya  2020-1-27          0       0          0
# 12798   Kenya  2020-1-28          0       0          0
# 12799   Kenya  2020-1-29          0       0          0
# 12800   Kenya  2020-1-30          0       0          0
# 12801   Kenya  2020-1-31          0       0          0
# 12802   Kenya   2020-2-1          0       0          0
# 12803   Kenya   2020-2-2          0       0          0
# 12804   Kenya   2020-2-3          0       0          0
# 12805   Kenya   2020-2-4          0       0          0
# 12806   Kenya   2020-2-5          0       0          0
# 12807   Kenya   2020-2-6          0       0          0
# 12808   Kenya   2020-2-7          0       0          0
# 12809   Kenya   2020-2-8          0       0          0
# 12810   Kenya   2020-2-9          0       0          0
# 12811   Kenya  2020-2-10          0       0          0

# %%
df_kenya.columns
# Out:
# Index(['country', 'date', 'confirmed', 'deaths', 'recovered'], dtype='object')

# %%
df_kenya["date"]
# Out:
# 12792    2020-1-22
# 12793    2020-1-23
# 12794    2020-1-24
# 12795    2020-1-25
# 12796    2020-1-26
#            ...
# 12943    2020-6-21
# 12944    2020-6-22
# 12945    2020-6-23
# 12946    2020-6-24
# 12947    2020-6-25
# Name: date, Length: 156, dtype: object

# %%
# Finding daily data
c = list(df_kenya['confirmed'])
c_new = [c[0]]
d = list(df_kenya['deaths'])
d_new = [d[0]]
r = list(df_kenya['recovered'])
r_new = [r[0]]

for a,b in zip(c,c[1:]):
    c_new.append(b-a)
for a,b in zip(d,d[1:]):
    d_new.append(b-a)
for a,b in zip(r,r[1:]):
    r_new.append(b-a)

df_kenya.loc[:,'date'] = pd.to_datetime(df_kenya['date']) # covert date column to type column
df_kenya['daily_confirmed'] = c_new
df_kenya['daily_deaths'] = d_new
df_kenya['daily_recoveries'] = r_new
df_kenya = df_kenya.set_index('date')
#data_pd.sort_values(by=['country'],inplace=True)
df_kenya.head(20)
# Out:
# C:\Users\Cheye\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\Cheye\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Cheye\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Cheye\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            country  confirmed  deaths  recovered  daily_confirmed  \
# date
# 2020-01-22   Kenya          0       0          0                0
# 2020-01-23   Kenya          0       0          0                0
# 2020-01-24   Kenya          0       0          0                0
# 2020-01-25   Kenya          0       0          0                0
# 2020-01-26   Kenya          0       0          0                0
# 2020-01-27   Kenya          0       0          0                0
# 2020-01-28   Kenya          0       0          0                0
# 2020-01-29   Kenya          0       0          0                0
# 2020-01-30   Kenya          0       0          0                0
# 2020-01-31   Kenya          0       0          0                0
# 2020-02-01   Kenya          0       0          0                0
# 2020-02-02   Kenya          0       0          0                0
# 2020-02-03   Kenya          0       0          0                0
# 2020-02-04   Kenya          0       0          0                0
# 2020-02-05   Kenya          0       0          0                0
# 2020-02-06   Kenya          0       0          0                0
# 2020-02-07   Kenya          0       0          0                0
# 2020-02-08   Kenya          0       0          0                0
# 2020-02-09   Kenya          0       0          0                0
# 2020-02-10   Kenya          0       0          0                0
#
#             daily_deaths  daily_recoveries
# date
# 2020-01-22             0                 0
# 2020-01-23             0                 0
# 2020-01-24             0                 0
# 2020-01-25             0                 0
# 2020-01-26             0                 0
# 2020-01-27             0                 0
# 2020-01-28             0                 0
# 2020-01-29             0                 0
# 2020-01-30             0                 0
# 2020-01-31             0                 0
# 2020-02-01             0                 0
# 2020-02-02             0                 0
# 2020-02-03             0                 0
# 2020-02-04             0                 0
# 2020-02-05             0                 0
# 2020-02-06             0                 0
# 2020-02-07             0                 0
# 2020-02-08             0                 0
# 2020-02-09             0                 0
# 2020-02-10             0                 0

# %%
features = ['daily_confirmed','daily_deaths','daily_recoveries']
df_kenya[features].hist(figsize=(18,6),layout=(1, 3));

# %%
df_kenya[features].plot(kind='density', subplots=True, layout=(1, 3), 
                  sharex=False, figsize=(18, 6));

# %%
plt.figure(figsize=(15, 7))
plt.plot(df_kenya['daily_confirmed'])
plt.show()

# %%
df_kenya.tail(10)
# Out:
#            country  confirmed  deaths  recovered  daily_confirmed  \
# date
# 2020-06-16   Kenya       3860     105       1328              133
# 2020-06-17   Kenya       4044     107       1353              184
# 2020-06-18   Kenya       4257     117       1459              213
# 2020-06-19   Kenya       4374     119       1550              117
# 2020-06-20   Kenya       4478     121       1586              104
# 2020-06-21   Kenya       4738     123       1607              260
# 2020-06-22   Kenya       4797     125       1680               59
# 2020-06-23   Kenya       4952     128       1782              155
# 2020-06-24   Kenya       5206     130       1823              254
# 2020-06-25   Kenya       5384     132       1857              178
#
#             daily_deaths  daily_recoveries
# date
# 2020-06-16             1                42
# 2020-06-17             2                25
# 2020-06-18            10               106
# 2020-06-19             2                91
# 2020-06-20             2                36
# 2020-06-21             2                21
# 2020-06-22             2                73
# 2020-06-23             3               102
# 2020-06-24             2                41
# 2020-06-25             2                34

# %%
df_kenya['daily_deaths'].sum()
# Out:
# 132
